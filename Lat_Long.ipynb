# %%
from opencage.geocoder import OpenCageGeocode
from pprint import pprint
import requests
import json
import pandas as pd
import time
#from config import w_key

# %%
path = "info/Aviation_Accident_Report_mine.csv"
aar_csv = pd.read_csv(path)
aar_csv
# Out:
#      Unnamed: 0 Report Number  \
# 0             0     ASR-20-06
# 1             1     ASR-20-05
# 2             2     AAR-20-02
# 3             3     ASR-20-04
# 4             4     AAR-20-01
# ..          ...           ...
# 475         514     AAR-67-AE
# 476         516     AAR-67-AB
# 477         517     AAR-67-AF
# 478         518     AAR-67-AD
# 479         519     AAR-67-AC
#
#                                             NTSB Title Accident Date  \
# 0    Provide Inspectors with Automatic Notification...     6/21/2019
# 1    F&M Enterprises and Stratus Oil Filter Adapter...    11/30/2020
# 2    Rapid Descent and Crash into Water Atlas Air I...     2/23/2019
# 3    Install Flight Data, Audio, and Image Recorder...      7/1/2017
# 4    Helicopter Air Ambulance Collision with Terrai...     1/29/2019
# ..                                                 ...           ...
# 475  ​Rexall Drug and Chemical Company Lear Jet 23,...     4/12/1966
# 476   ​Lear Jet Corporation, Lear Jet Model 23, N8041J    10/21/1965
# 477            ​West Coast Airlines, Inc., DC-9, N9101     10/1/1966
# 478   ​Japan Air Lines, Ltd., Douglas DC-8-33, JA-8006    12/25/1965
# 479  ​Paul Kelly Flying Service, Inc., Lear Jet 23,...    11/14/1965
#
#     Report Date           City     State
# 0    12/16/2020       Mokuleia        HI
# 1    11/30/2020       Multiple  Multiple
# 2     7/14/2020    Trinity Bay        TX
# 3     5/19/2020       Multiple  Multiple
# 4     5/19/2020        Zaleski        OH
# ..          ...            ...       ...
# 475  12/19/1967      Clarendon        TX
# 476  12/11/1967        Jackson        MI
# 477  12/11/1967          Wemme        OR
# 478   6/26/1967  San Francisco        CA
# 479   6/19/1967   Palm Springs        CA
#
# [480 rows x 7 columns]

# %%
cities = aar_csv["City"].to_list()
states = aar_csv["State"].to_list()

key = ""

lati = []
longi = []


for (city, state) in zip(cities, states):
    try:
        geocoder = OpenCageGeocode(key)
        query = f'{city}, {state}'
        results = geocoder.geocode(query)
        lat = results[0]['geometry']['lat']
        lng = results[0]['geometry']['lng']
        lati.append(lat)
        longi.append(lng)
        time.sleep(1)
    except KeyError:
        print(city)

# %%
aar_csv['Latitude'] = lati
aar_csv['Longitude'] = longi

# %%
aar_csv
aar_csv.to_csv('info/aviation_and_coordinates.csv', index = False)
